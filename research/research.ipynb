# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (7.2.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (9.12.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (26.1)
# Requirement already satisfied: psutil>=5.7 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Krishanu Das\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jupyter-client>=8.8.0->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.6)
# Requirement already satisfied: six>=1.5 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\Users\Krishanu Das\AppData\Local\Programs\Python\Python312\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\Krishanu Das\AppData\Roaming\Python\Python312\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
example = {"Key1": "Value1", "Key2": "Value2"}

# %%
example["Key1"]
# Out:
# 'Value1'

# %%
pip install ConfigBox
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement ConfigBox (from versions: none)
# ERROR: No matching distribution found for ConfigBox

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from box import ConfigBox
#
# ModuleNotFoundError: No module named 'box'

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\krishanu das\appdata\local\programs\python\python312\lib\site-packages (24.3.1)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 4.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# Successfully installed pip-26.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox

# %%
example = ConfigBox({"Key1": "Value1", "Key2": "Value2"})
example.Key1
# Out:
# 'Value1'

# %%
## explanation is ensure annotation
from ensure import ensure_annotations

@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(2, 3)
# Out:
# 6
